# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/10-423_GenAI/handout_hw3'
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/10-423_GenAI/handout_hw3
# /content/drive/My Drive/Colab Notebooks/10-423_GenAI/handout_hw3

# %%
# !pip install -r requirements.txt

# %%
# !python train.py config/finetune_params_config.py --init_from="gpt2-medium" --out_dir="rank196_alpha784" --lora_rank=196 --lora_alpha=784
# Out:
# 2024-03-04 00:12:26.019194: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-04 00:12:26.019248: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-04 00:12:26.020813: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-04 00:12:27.335997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# wandb: Currently logged in as: tczhang. Use `wandb login --relogin` to force relogin
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Overriding config with config/finetune_params_config.py:
# ...

# %%
# !python generate.py --init_from="gpt2-medium"
# Out:
# loading weights from pretrained gpt: gpt2-medium
# forcing vocab_size=50257, block_size=1024, bias=True
# overriding dropout rate to 0.0
# number of parameters: 353.77M
# positive 	  telling. Let the to
# negative 	  perceived negativel
# positive 	  for so his style in
# positive 	  positive and if the
# negative 	  both above average
# negative 	  usually judged as u
# negative 	  positive, however,
# negative 	  good and the but no
# negative 	  correct. Go for.
# negative 	  more reflective:Not
# negative 	  then more pressing
# negative 	  100: most have they
# negative 	  of and at once the
# negative 	 : there is there is
# negative 	  not to be positive
# positive 	  the comment or the
# positive 	  actually positive:
# positive 	  a little- " zero
# negative 	  the negative respon
# positive 	  positive right but
# negative 	  positive.We started
# positive 	  almost to say?the
# negative 	  positive or negativ
# positive 	  always more positiv
# ...

# %%
# !python generate.py --init_from="resume" --out_dir="full_fine_tune"
# Out:
# number of parameters: 353.77M
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# ...

# %%
# !python generate.py --init_from="resume" --out_dir="rank16_alpha64"
# Out:
# number of parameters: 356.13M
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# ...

# %%
# !python generate.py --init_from="resume" --out_dir="rank128_alpha512"
# Out:
# number of parameters: 372.65M
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# ...

# %%
# !python generate.py --init_from="resume" --out_dir="rank196_alpha784"
# Out:
# number of parameters: 382.68M
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  negative.<|endoftex
# negative 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# positive 	  positive.<|endoftex
# negative 	  negative.<|endoftex
# ...
